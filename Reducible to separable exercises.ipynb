# %% [markdown]
# ### Exercise 1

# %% [markdown]
# $$\quad
# \frac {dy}{dx} = (x+y+1)^2
# $$
# Change of variable :
# $$\quad:
# u=(x+y+1)
# \quad \frac {du}{dx} = 1+\frac {dy}{dx}
# $$
# As:
# $$\quad
#  \frac {dy}{dx} = u^2
# \quad u = tan (x+c)
# $$
# Finally:
# $$\quad
# y= tan(x+c)-x-1
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import math


def dy_dx(y, x):
    return (x+y+1)**2

xs = np.linspace(0,10,100)
y0 = 0  # the initial condition
ys = odeint(dy_dx, y0, xs)
ys = np.array(ys).flatten()

plt.rcParams.update({'font.size': 14})  # increase the font size
plt.xlabel("x")
plt.ylabel("y")
plt.plot(xs, ys);

# %%
print(xs)
y_exact_1 = np.tan(xs+1)-xs-1 
y_exact_2 = np.tan(xs+2)-xs-1 
y_difference = ys - y_exact
plt.plot( xs, y_exact_1,xs,y_exact_2 ,"+");
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %%
y_diff_1 = np.abs(y_exact_1 - ys)
y_diff_2 = np.abs(y_exact_2 - ys)
plt.semilogy(xs, y_diff_1)
plt.semilogy(xs, y_diff_2)
plt.ylabel("Error")
plt.xlabel("x")
# Out:
# C:\Users\alera\Anaconda3\lib\site-packages\numpy\ma\core.py:6666: RuntimeWarning: overflow encountered in power
#   result = np.where(m, fa, umath.power(fa, fb)).view(basetype)
# Text(0.5, 0, 'x')

# %% [markdown]
# ### Exercise 2
# $$
# \quad
# x(\frac {dy}{dx})=y(x^2*y^2-1)
# $$
# $$
# \quad
# u=xy \rightarrow y=\frac {u}{x}
# $$
# $$
# \quad
# du = y + x(\frac {dy}{dx})
# $$
# As:
# $$
# x(\frac {dy}{dx})=\frac {u}{x}(u^2-1)
# $$
# $$\quad
# du= \frac{u^3}{x}
# $$

# %% [markdown]
# Finally, solving the integral :
# $$\quad
# \int \frac{du}{u^3} = \int \frac{dx}{x}
# $$
# We find the analytical solution:
# $$
# \quad
# y=\frac{1}{x}* \sqrt{\frac{1}{2(k-ln|x|)}}
# $$

# %%
def dy_dx(y, x):
    return (y/x)*((x**2)*(y**2)-1)

xs = np.linspace(0,10,100)
y0 = 0  # the initial condition
ys = odeint(dy_dx, y0, xs)
ys = np.array(ys).flatten()

plt.rcParams.update({'font.size': 14})  # increase the font size
plt.xlabel("x")
plt.ylabel("y")
plt.plot(xs, ys);
# Out:
# C:\Users\alera\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide

# %%
y_exact_1= (1/xs)*(np.sqrt(1/(2*(0.5-np.log(xs)))))
y_exact_2= (1/xs)*(np.sqrt(1/(2*(6.08-np.log(xs)))))
plt.plot( xs, y_exact_1,xs,y_exact_2,"+");
# Out:
# C:\Users\alera\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# C:\Users\alera\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# C:\Users\alera\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in sqrt
#   """Entry point for launching an IPython kernel.
# C:\Users\alera\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in multiply
#   """Entry point for launching an IPython kernel.
# C:\Users\alera\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
#
# C:\Users\alera\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# ...

# %%
y_diff_1 = np.abs(y_exact_1 - ys)
y_diff_2 = np.abs(y_exact_2 - ys)
plt.semilogy(xs, y_diff_1)
plt.semilogy(xs, y_diff_2)
plt.ylabel("Error")
plt.xlabel("x")
# Out:
# Text(0.5, 0, 'x')
